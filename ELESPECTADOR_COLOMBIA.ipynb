# %%
from urllib.request import urlopen

# %%
from urllib.error import HTTPError

# %%
from bs4 import BeautifulSoup

# %%
try:

    html = urlopen("https://www.elespectador.com/noticias/")
    
except HTTPError as e:

    print(e)

else:

    res = BeautifulSoup(html.read(),"html")

    print(res.title)
# Out:
# <title>Últimas noticias de Argentina y el mundo - LA NACION</title>

# %%
tags = res.findAll("h2", {"class": ""})

# %%
from urllib.request import urlopen

from urllib.error import HTTPError

from urllib.error import URLError

from bs4 import BeautifulSoup

try:

    html = urlopen("https://www.elespectador.com/noticias/")

except HTTPError as e:

    print(e)

except URLError:

    print("Server down or incorrect domain")

else:

    res = BeautifulSoup(html.read(),"html")

    tags = res.findAll("h2", {"class": ""})

# %%
for tag in tags:

        print(tag.getText())
# Out:
# Ventas en Colombia cayeron 48 % durante la cuarentena
# Jorge Rodrigo Tovar, hijo de “Jorge 40”, es el nuevo coordinador de víctimas del Mininterior
# Falsos positivos: las cuentas pendientes de un reclutador del Batallón Jaime Rooke
# #LasIgualadas - ¿Cómo estudia la gente en casa si no tienen Internet?
# ¿Qué pasa con los subsidios de servicios públicos en Bogotá?
# Magistrada Lombana pide salir de la investigación por supuestos seguimientos desde el Ejército
# Gobierno español insiste en mantener límites de movilidad pese a protestas
# Semana Mundial del Parto Respetado: mi cuerpo, mis decisiones
# Colombia formará parte del Comité Ejecutivo de la OMS
# El Triple, el batazo más difícil del béisbol
# Linson Palacios, una víctima desalojada en medio de la pandemia
# Así serán los tres días sin IVA y la suspensión del cobro del impoconsumo en restaurantes
# Colombia tiene el mejor sitio web de turismo en el mundo
# ...

# %%
import pandas as pd

# %%
weather = pd.DataFrame({
    "noticias": tags,
   
})
weather
# Out:
#                                              noticias
# 0   [[Ventas en Colombia cayeron 48 % durante la c...
# 1   [[Jorge Rodrigo Tovar, hijo de “Jorge 40”, es ...
# 2   [[Falsos positivos: las cuentas pendientes de ...
# 3   [[#LasIgualadas - ¿Cómo estudia la gente en ca...
# 4   [[¿Qué pasa con los subsidios de servicios púb...
# 5   [[Magistrada Lombana pide salir de la investig...
# 6   [[Gobierno español insiste en mantener límites...
# 7   [[Semana Mundial del Parto Respetado: mi cuerp...
# 8   [[Colombia formará parte del Comité Ejecutivo ...
# 9    [[El Triple, el batazo más difícil del béisbol]]
# 10  [[Linson Palacios, una víctima desalojada en m...
# 11  [[Así serán los tres días sin IVA y la suspens...
# 12  [[Colombia tiene el mejor sitio web de turismo...
# 13  [[“La decisión del hotel fue hacerme la vida i...
# 14  [[Llega a la Cámara proyecto que busca reglame...
# 15  [[Denuncian amenazas contra exguerrilleros en ...
# ...

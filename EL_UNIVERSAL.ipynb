# %% [markdown]
# # DESCARGAR LA PÁGINA

# %%
import requests

# %%
page = requests.get("https://www.eluniversal.com.mx/")

# %% [markdown]
# # VER ES ESTADO DE LA DESCARGA

# %%
page
# Out:
# <Response [200]>

# %%
page.status_code
# Out:
# 200

# %% [markdown]
# # IMPRIMIR EL CONTENIDO DESCARGADO

# %%
page.content
# Out:
# b'<!DOCTYPE HTML>\n<html lang="es" dir="ltr" xmlns="https://www.w3.org/1999/xhtml" prefix="og: https://ogp.me/ns# article: https://ogp.me/ns/article# book: https://ogp.me/ns/book# profile: https://ogp.me/ns/profile# video: https://ogp.me/ns/video#">\n<head>\n<script>\n  var nua = "nav"+"igator.u"+"serAgent";\n\n  if (window.location.pathname == \'/\'){\n    var isMobile = false; //initiate as false\n    if(/(android|bb\\d+|meego).+mobile|avantgo|bada\\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|Android|Silk|lge |maemo|midp|mmp|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test(eval(nua))\n        || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\\-(n|u)|c55\\/|capi|cc
# ...

# %% [markdown]
# # --ANALIZAR CON BEAUTIFULSOUP--

# %% [markdown]
# # AÑADIR LA BIBLIOTECA

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# # IMPRIMIR EL TEXTO ANALIZADO

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html dir="ltr" lang="es" prefix="og: https://ogp.me/ns# article: https://ogp.me/ns/article# book: https://ogp.me/ns/book# profile: https://ogp.me/ns/profile# video: https://ogp.me/ns/video#" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#   <script>
#    var nua = "nav"+"igator.u"+"serAgent";
#
#   if (window.location.pathname == '/'){
#     var isMobile = false; //initiate as false
#     if(/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|Android|Silk|lge |maemo|midp|mmp|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test(eval(nua))
# ...

# %% [markdown]
# # EXTRAER LO QUE SE ENCUENTRA DENTRO DE LAS CLASES

# %%
panel= soup.find(class_="panel-panel grid-11 alpha")

# %%
forecast_items = panel(class_="multimedia")##

# %%
tonight = forecast_items[0]

# %%
print(tonight.prettify())
# Out:
# <div class="multimedia">
#  <div class="views-field views-field-views-conditional-1">
#   <span class="field-content">
#   </span>
#  </div>
#  <div class="views-field views-field-views-conditional">
#   <div class="field-content iconoWrapperBig">
#    <div class="view view-notas-relacionadas view-id-notas_relacionadas view-display-id-panel_pane_6 iconoTipo view-dom-id-b5b1bf2ad101f0479d507b0350dee0a5">
#     <div class="view-content">
#      <div>
#      </div>
#     </div>
#    </div>
#    <a href="/nacion/coronavirus-6-de-mayo-mexico-acumula-2-mil-704-muertos-por-covid-19-hay-27634-casos">
#     <img alt="México acumula 2 mil 704 muertos por Covid-19; hay 27,634 casos" data-src="https://www.eluniversal.com.mx/sites/default/files/styles/f08-441x271/public/2020/05/06/alomia.jpeg?itok=bZoBSymA" height="271" src="https://www.eluniversal.com.mx/sites/all/modules/lazyloader/image_placeholder.gif" title="México acumula 2 mil 704 muertos por Covid-19; hay 27,634 casos" width="441"/>
# ...

# %%
period = tonight.find(class_="field-content").get_text()

# %%
print(period)

# %% [markdown]
# # EXTRAER LOS ELEMENTOS DE UNA CLASE

# %%
period_tags = panel.select(".multimedia .field-content ")

# %%
periods = [pt.get_text() for pt in period_tags]

# %%
periods
# Out:
# ['',
#  '\n\n\n\n\n\n',
#  ' México acumula 2 mil 704 muertos por Covid-19; hay 27,634 casos ',
#  'Nación',
#  '19:05',
#  'Sigue aquí la transmisión completa de la conferencia sobre casos de coronavirus en México, desde Palacio Nacional\n',
#  '',
#  '\n\n\n\n\n\n',
#  ' IMSS acata freno a difusión de cartas firmadas por AMLO: Zoé Robledo ',
#  'Nación',
#  '19:28',
#  'Este miércoles el TEPJF confirmó el cese cautelar de la distribución de cientos de miles de cartas a beneficiarios de créditos solidarios, pero con promoción personalizada del presidente Andrés Manuel López Obrador',
#  '',
#  '\n\n\n\n\n\n',
#  ' Se fugan en un túnel 12 internos del penal de Cieneguillas, Zacatecas ',
#  'Estados',
#  '19:10',
#  'Autoridades penitenciarias informaron que los internos cavaron y utilizaron un túnel de aproximadamente 50 metros que daba al exterior para salir',
#  '',
#  '\n\n\n\n\n\n',
#  ' Ignoran cuarentena y hacen enormes filas para comprar cerveza en Sonora ',
#  'Estados',
# ...

# %% [markdown]
# # --USAR DATAFRAME-- (Analizar los datos)

# %% [markdown]
# # IMPORTAR PANDAS

# %%
import pandas as pd

# %%
weather = pd.DataFrame({
    "noticias": periods,
    
})
weather
# Out:
#                                              noticias
# 0
# 1                                        \n\n\n\n\n\n
# 2    México acumula 2 mil 704 muertos por Covid-19...
# 3                                              Nación
# 4                                               19:05
# 5   Sigue aquí la transmisión completa de la confe...
# 6
# 7                                        \n\n\n\n\n\n
# 8    IMSS acata freno a difusión de cartas firmada...
# 9                                              Nación
# 10                                              19:28
# 11  Este miércoles el TEPJF confirmó el cese caute...
# 12
# 13                                       \n\n\n\n\n\n
# 14   Se fugan en un túnel 12 internos del penal de...
# 15                                            Estados
# 16                                              19:10
# 17  Autoridades penitenciarias informaron que los ...
# 18
# 19                                       \n\n\n\n\n\n
# ...

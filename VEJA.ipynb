# %%
from urllib.request import urlopen

# %%
from urllib.error import HTTPError

# %%
from bs4 import BeautifulSoup

# %%
try:

    html = urlopen("https://veja.abril.com.br/")
    
except HTTPError as e:

    print(e)

else:

    res = BeautifulSoup(html.read(),"html")

    print(res.title)
# Out:
# <title>VEJA - Reportagens exclusivas, notícias, informação e opinião.</title>

# %%
tags = res.findAll("h3", {"class": "title"})

# %%
from urllib.request import urlopen

from urllib.error import HTTPError

from urllib.error import URLError

from bs4 import BeautifulSoup

try:

    html = urlopen("https://veja.abril.com.br/")

except HTTPError as e:

    print(e)

except URLError:

    print("Server down or incorrect domain")

else:

    res = BeautifulSoup(html.read(),"html")

    tags = res.findAll("h3", {"class": "title"})

# %%
for tag in tags:

        print(tag.getText())
# Out:
# Acompanhe as últimas notícias sobre a infecção no Brasil e no mundo
# Brasil ultrapassa 250 mil casos de coronavírus e tem 16.792 mortes
# Primeira vacina testada em humanos tem resultado inicial positivo
# MPF vai apurar vazamento de informações da Operação Furna da Onça
# Celso de Mello decidirá sobre divulgação de vídeo até o final da semana
# Defesa alega risco de Covid-19 para soltar dupla que é contra a quarentena
# Próximo foco da Covid-19, Pará procura Mandetta para se aconselhar
# Teich ataca Mandetta por dizer que ele não fez nada na Saúde
# Elon Musk: um gênio que se tornou o ícone do negacionismo da Covid
# Uma Porto Alegre foi desmatada na Amazônia no mês de abril
# PGR pede abertura de inquérito contra Helder Barbalho no STJ
# Após dois meses, papa celebra primeira missa para fiéis
# Planalto controla cartazes por medo do inquérito do STF
# As ilusões do presidente sobre a recuperação pós-pandemia
# Pela blindagem total e definitiva da PF (e de seus quadros)
# Depois de Teich, quem será o próximo a cair?
# Os sete sintomas conhecidos da Covid-19 na pele
# Witzel procura substituto para André Moura no governo do Rio
# Governador do Piauí nega Damares: 'Não há remédio milagroso contra Covid'
# Coronavírus pode reduzir receita de hospitais privados em 30%
# Vagas para profissionais de saúde e educação têm crescimento de até 6.900%
# Rio cria comitê para fiscalizar hospitais de campanha
# Possível vacina injeta ânimo nos investidores, e bolsa sobe 5%
# Alemanha e Espanha anunciam planos para reabrir fronteiras
# Suíça, Itália e China reabrem museus com ressalvas
# Interferon acelera recuperação dos pacientes, comprova estudo
# Chinesas focam em medianos para conquistar brasileiros
# Churrascaria carioca ignora decreto e funciona normalmente
# Vinte anos depois, 'Harry Potter' segue essencial
# A agressividade do surto periga vencer o SUS, acrescentando nomes ao drama
# Barulhento inquérito de Moro e Bolsonaro marca despedida de Celso de Mello do STF
# A estrela cai: Lula era mais popular e influente quando estava na prisão, em Curitiba
# Juan Guaidó: na pandemia, efeitos da ditadura ameaçam países vizinhos
# Abilio Diniz: Sergio Moro criou tensão, mas Paulo Guedes acalmou o mercado
# ‘O germe do golpe não existe mais no Brasil’, diz Luís Roberto Barroso

# %%
import pandas as pd

# %%
weather = pd.DataFrame({
    "noticias": tags,
   
})
weather
# Out:
#                                              noticias
# 0   [Acompanhe as últimas notícias sobre a infecçã...
# 1   [Brasil ultrapassa 250 mil casos de coronavíru...
# 2   [Primeira vacina testada em humanos tem result...
# 3   [MPF vai apurar vazamento de informações da Op...
# 4   [Celso de Mello decidirá sobre divulgação de v...
# 5   [Defesa alega risco de Covid-19 para soltar du...
# 6   [Próximo foco da Covid-19, Pará procura Mandet...
# 7   [Teich ataca Mandetta por dizer que ele não fe...
# 8   [Elon Musk: um gênio que se tornou o ícone do ...
# 9   [Uma Porto Alegre foi desmatada na Amazônia no...
# 10  [PGR pede abertura de inquérito contra Helder ...
# 11  [Após dois meses, papa celebra primeira missa ...
# 12  [Planalto controla cartazes por medo do inquér...
# 13  [As ilusões do presidente sobre a recuperação ...
# 14  [Pela blindagem total e definitiva da PF (e de...
# 15     [Depois de Teich, quem será o próximo a cair?]
# 16  [Os sete sintomas conhecidos da Covid-19 na pele]
# 17  [Witzel procura substituto para André Moura no...
# 18  [Governador do Piauí nega Damares: 'Não há rem...
# 19  [Coronavírus pode reduzir receita de hospitais...
# 20  [Vagas para profissionais de saúde e educação ...
# 21  [Rio cria comitê para fiscalizar hospitais de ...
# 22  [Possível vacina injeta ânimo nos investidores...
# 23  [Alemanha e Espanha anunciam planos para reabr...
# 24  [Suíça, Itália e China reabrem museus com ress...
# 25  [Interferon acelera recuperação dos pacientes,...
# 26  [Chinesas focam em medianos para conquistar br...
# 27  [Churrascaria carioca ignora decreto e funcion...
# 28  [Vinte anos depois, 'Harry Potter' segue essen...
# 29  [A agressividade do surto periga vencer o SUS,...
# 30  [Barulhento inquérito de Moro e Bolsonaro marc...
# 31  [A estrela cai: Lula era mais popular e influe...
# 32  [Juan Guaidó: na pandemia, efeitos da ditadura...
# 33  [Abilio Diniz: Sergio Moro criou tensão, mas P...
# 34  [‘O germe do golpe não existe mais no Brasil’,...
